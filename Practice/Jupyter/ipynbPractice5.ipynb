# %% [markdown]
# # Python TypeCasting

# %%
int(10.3)
# Out:
# 10

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(2+3j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 int(2+3j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')
# Out:
# 10

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
float(25)
# Out:
# 25.0

# %%
float(25,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 float(25,30)
#
# TypeError: float expected at most 1 argument, got 2

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 float(1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('9')
# Out:
# 9.0

# %%
float('nine')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 float('nine')
#
# ValueError: could not convert string to float: 'nine'

# %%
complex(8)
# Out:
# (8+0j)

# %%
complex(8+10j)
# Out:
# (8+10j)

# %%
complex(8,10)
# Out:
# (8+10j)

# %%
complex(2,4,6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 complex(2,4,6)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(2.3,3.3)
# Out:
# (2.3+3.3j)

# %%
complex(4.5)
# Out:
# (4.5+0j)

# %%
complex(True,False)
# Out:
# (1+0j)

# %%
complex(False,True)
# Out:
# 1j

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 complex('ten')
#
# ValueError: complex() arg is a malformed string

# %%
complex('10','20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 complex('10','20')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex('10',20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 complex('10',20)
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex(10,'20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 complex(10,'20')
#
# TypeError: complex() second arg can't be a string

# %%
print(str(2))
print(str(2.3))
print(str(True))
print(str(1+2j))
# Out:
# 2
# 2.3
# True
# (1+2j)

# %%
str(2)
# Out:
# '2'

# %%
str(2.3)
# Out:
# '2.3'

# %%
str(True)
# Out:
# 'True'

# %%
str(1+2j)
# Out:
# '(1+2j)'

# %%
bool(2)
# Out:
# True

# %%
bool(2.3)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool()
# Out:
# False

# %%
bool(1+2j)
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
print(10)
print(10,20)
print('Hi')
print(1,2,'hi')
# Out:
# 10
# 10 20
# Hi
# 1 2 hi

# %%
n1, n2 = 1,2
add = n1+n2
print(add)
# Out:
# 3

# %%
print('i casually added', n1 , 'and' , n2, ', the result is', add)
# Out:
# i casually added 1 and 2 , the result is 3

# %%
num1=100
num2=25
num3=20
avg=(num1+num2+num3)/3
avg1=round((num1+num2+num3)/3,2)
print('the average of {},{}, and {} is = {} or {}' .format(num1,num2,num3,avg,avg1))
# Out:
# the average of 100,25, and 20 is = 48.333333333333336 or 48.33

# %%
n1,n2 = 100,200
add = n1+n2
print(f'the addition of {n1} and {n2} is {add}')
# Out:
# the addition of 100 and 200 is 300

# %%
print('Good', end = ' ')
print('Morning')
# Out:
# Good Morning

# %%
print('hi','hello','how','are','you', sep='--->')
# Out:
# hi--->hello--->how--->are--->you
