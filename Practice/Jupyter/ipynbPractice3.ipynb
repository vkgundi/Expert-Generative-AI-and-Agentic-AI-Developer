# %% [markdown]
# 28th

# %%
v=1

# %%
v
# Out:
# 1

# %%
id(v)
# Out:
# 140724143895464

# %%
nit=2

# %%
nit
# Out:
# 2

# %%
8 = nit
# Out:
#   Cell In[8], line 1
#     8 = nit
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
v8 = nit

# %%
v8
# Out:
# 2

# %%
8v = 6
# Out:
#   Cell In[11], line 1
#     8v = 6
#     ^
# SyntaxError: invalid decimal literal

# %%
nit$ = 10
# Out:
#   Cell In[12], line 1
#     nit$ = 10
#        ^
# SyntaxError: invalid syntax

# %%
gvk = 9
gvk
# Out:
# 9

# %%
a='vamshi'
b='krishna'

# %%
int.__add__(a,b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 int.__add__(a,b)
#
# TypeError: descriptor '__add__' requires a 'int' object but received a 'str'

# %%
str.__add__(a,b)
# Out:
# 'vamshikrishna'

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import keyword
len(keyword.kwlist)
# Out:
# 35

# %%
def = 29
def
# Out:
#   Cell In[23], line 1
#     def = 29
#         ^
# SyntaxError: invalid syntax

# %%
DEF = 29
DEF
# Out:
# 29

# %% [markdown]
# Rules of Python Variables:
#
# - case sensitive
# - keywords cannot be used as variables
# - special characters not allowed except _ (underscore)
# - Does not start with digit but ends with digit
#
# pythob variable = value
# value is also called as datatypes
# Example:
# - int
# - float
# - Boolean
# - Complex
# - string

# %%
3+1
2+1
# Out:
# 3

# %%
print(3+1)
print(2+1)
# Out:
# 4
# 3
