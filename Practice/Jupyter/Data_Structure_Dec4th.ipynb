# %% [markdown]
# # Python Data Structure

# %% [markdown]
# - list
# - tuple
# - set
# - dict

# %%
l = []
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l
# Out:
# []

# %%
l.append(10)

# %%
l
# Out:
# [10]

# %%
l.append(20)
l
# Out:
# [10, 20]

# %%
l.append(30)
l
# Out:
# [10, 20, 30]

# %%
l.append(40)
l.append(50)
l.append(60)

# %%
l
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
l1 = l.copy()
l1
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 60]
# [10, 20, 30, 40, 50, 60]

# %%
l1.append('hi',1+3j,2.3,True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 l1.append('hi',1+3j,2.3,True)
#
# TypeError: list.append() takes exactly one argument (4 given)

# %%
l1.append(2.4)
l1.append(True)
l1.append(1+4j)
l1.append('Hi')

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 2.4, True, (1+4j), 'Hi']

# %%
print(len(l))
print(len(l1))
# Out:
# 6
# 10

# %%
l
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
l.append(10)

# %%
l
# Out:
# [10, 20, 30, 40, 50, 60, 10]

# %%
l3=[1,2,3,4,5,6,7,8,'vamshi','krishna',1+2j, True]

# %%
l3
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 'vamshi', 'krishna', (1+2j), True]

# %%
l3.clear()

# %%
l3
# Out:
# []

# %%
del l3  #deletes the variable

# %%
l3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 l3
#
# NameError: name 'l3' is not defined

# %%
l
# Out:
# [10, 20, 30, 40, 50, 60, 10]

# %%
l.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 l.count()
#
# TypeError: list.count() takes exactly one argument (0 given)

# %%
l.count
# Out:
# <function list.count(value, /)>

# %%
l.count(10)
# Out:
# 2

# %%
l.count(20)
# Out:
# 1

# %%
l
# Out:
# [10, 20, 30, 40, 50, 60, 10]

# %%
l[:]
# Out:
# [10, 20, 30, 40, 50, 60, 10]

# %%
l[2:]
# Out:
# [30, 40, 50, 60, 10]

# %%
l[:5]
# Out:
# [10, 20, 30, 40, 50]

# %%
l[:-1]
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 60, 10]

# %%
l[::-1]
# Out:
# [10, 60, 50, 40, 30, 20, 10]

# %%
l[:::-1]
# Out:
#   Cell In[46], line 1
#     l[:::-1]
#         ^
# SyntaxError: invalid syntax

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 2.4, True, (1+4j), 'Hi']

# %%
l1.index('Hi')
# Out:
# 9

# %%
l1[9]
# Out:
# 'Hi'

# %%
l[::1]
# Out:
# [10, 20, 30, 40, 50, 60, 10]

# %%
l[::2]
# Out:
# [10, 30, 50, 10]

# %%
l[::-2]
# Out:
# [10, 50, 30, 10]

# %%
l
# Out:
# [10, 20, 30, 40, 50, 60, 10]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 2.4, True, (1+4j), 'Hi']

# %%
l1[1:10:3]
# Out:
# [20, 50, True]

# %%
l1.append(100)

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 2.4, True, (1+4j), 'Hi', 100]

# %%
l1[1:10:3]
# Out:
# [20, 50, True]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 2.4, True, (1+4j), 'Hi', 100]

# %%
l1[1:10:3]
# Out:
# [20, 50, True]

# %%
l1.append(20,50,60)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 l1.append(20,50,60)
#
# TypeError: list.append() takes exactly one argument (3 given)

# %%
l1.append(20)
l1.append(50)
l1.append(70)

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 2.4, True, (1+4j), 'Hi', 100, 20, 50, 70]

# %%
l1[1:15:3]
# Out:
# [20, 50, True, 100, 70]
