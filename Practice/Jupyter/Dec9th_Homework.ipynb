# %% [markdown]
# # Strip

# %%
txt = "   abc  def  ghi   "
txt.lstrip()
# Out:
# 'abc  def  ghi   '

# %%
txt.rstrip()
# Out:
# '   abc  def  ghi'

# %%
txt.strip()
# Out:
# 'abc  def  ghi'

# %% [markdown]
# # Escape Character

# %%
gvk = "my favourite color is "Gray""
# Out:
#   Cell In[4], line 1
#     gvk = "my favourite color is "Gray""
#                                   ^
# SyntaxError: invalid syntax

# %%
gvk = "my favourite color is \"Gray\""

# %%
gvk
# Out:
# 'my favourite color is "Gray"'

# %% [markdown]
# # List

# %%
l1=[]

# %%
l1
# Out:
# []

# %%
print(type(l1))
# Out:
# <class 'list'>

# %%
type(l1)
# Out:
# list

# %%
l1=[10,20,30,40,50,'Hi',True,1+2j,1234.454]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 'Hi', True, (1+2j), 1234.454]

# %%
l1[0]
# Out:
# 10

# %%
l1[-1]
# Out:
# 1234.454

# %%
l1[1:6]
# Out:
# [20, 30, 40, 50, 'Hi']

# %%
l1[:-1]
# Out:
# [10, 20, 30, 40, 50, 'Hi', True, (1+2j)]

# %%
l1[2:-1]
# Out:
# [30, 40, 50, 'Hi', True, (1+2j)]

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 'Hi', True, (1+2j), 1234.454]

# %%
l1[-1:]
# Out:
# [1234.454]

# %%
l1[::-1]
# Out:
# [1234.454, (1+2j), True, 'Hi', 50, 40, 30, 20, 10]

# %%
l1[1::]
# Out:
# [20, 30, 40, 50, 'Hi', True, (1+2j), 1234.454]

# %%
l2=['one', 'two', 'three']

# %%
l2
# Out:
# ['one', 'two', 'three']

# %%
l2.append("nine")

# %%
l2
# Out:
# ['one', 'two', 'three', 'nine']

# %%
l2.insert(3, 'four')

# %%
l2
# Out:
# ['one', 'two', 'three', 'four', 'nine']

# %%
l2.insert(1,'one')

# %%
l2
# Out:
# ['one', 'one', 'two', 'three', 'four', 'nine']

# %%
l2.remove('one')

# %%
l2
# Out:
# ['one', 'two', 'three', 'four', 'nine']

# %%
l2.pop()
# Out:
# 'nine'

# %%
l2
# Out:
# ['one', 'two', 'three', 'four']

# %%
l2.pop(3)
# Out:
# 'four'

# %%
l2
# Out:
# ['one', 'two', 'three']

# %%
del l1[2]

# %%
l2
# Out:
# ['one', 'two', 'three']

# %%
l1
# Out:
# [10, 20, 40, 50, 'Hi', True, (1+2j), 1234.454]

# %%
del l1[2]

# %%
l2
# Out:
# ['one', 'two', 'three']

# %%
l1
# Out:
# [10, 20, 50, 'Hi', True, (1+2j), 1234.454]

# %%
l1[2]=30
l1
# Out:
# [10, 20, 30, 'Hi', True, (1+2j), 1234.454]

# %%
l2
# Out:
# ['one', 'two', 'three']

# %%
l2.clear()

# %%
l2
# Out:
# []

# %%
del l2

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
l1
# Out:
# [10, 20, 30, 'Hi', True, (1+2j), 1234.454]

# %%
l2=l1

# %%
l2
# Out:
# [10, 20, 30, 'Hi', True, (1+2j), 1234.454]

# %%
id(l1) , id(l2)
# Out:
# (1770956042624, 1770956042624)

# %%
l3= l1.copy()

# %%
l3
# Out:
# [10, 20, 30, 'Hi', True, (1+2j), 1234.454]

# %%
id(l3)
# Out:
# 1770974451776

# %%
l1[0]=0

# %%
l1
# Out:
# [0, 20, 30, 'Hi', True, (1+2j), 1234.454]

# %%
l2
# Out:
# [0, 20, 30, 'Hi', True, (1+2j), 1234.454]

# %%
l3
# Out:
# [10, 20, 30, 'Hi', True, (1+2j), 1234.454]

# %%
l1=l2+l3

# %%
l1
# Out:
# [0,
#  20,
#  30,
#  'Hi',
#  True,
#  (1+2j),
#  1234.454,
#  10,
#  20,
#  30,
#  'Hi',
#  True,
#  (1+2j),
#  1234.454]

# %%
l1.extend(l2)

# %%
l1
# Out:
# [0,
#  20,
#  30,
#  'Hi',
#  True,
#  (1+2j),
#  1234.454,
#  10,
#  20,
#  30,
#  'Hi',
#  True,
#  (1+2j),
#  1234.454,
#  0,
#  20,
#  30,
#  'Hi',
#  True,
#  (1+2j),
#  1234.454]

# %%
l2
# Out:
# [0, 20, 30, 'Hi', True, (1+2j), 1234.454]

# %%
1121 in l2
# Out:
# False

# %%
0 in l1
# Out:
# True

# %%
if True in l1:
    print('True is present in L1')
else:
    print('True is not present in L1')
# Out:
# True is present in L1

# %%
if 'Australia'in l1:
    print('Australia is present in L1')
else:
    print('Australia is not present in L1')
# Out:
# Australia is not present in L1

# %%
l3
# Out:
# [10, 20, 30, 'Hi', True, (1+2j), 1234.454]

# %%
l3.reverse()

# %%
l3
# Out:
# [1234.454, (1+2j), True, 'Hi', 30, 20, 10]

# %%
l3.reverse()

# %%
l3
# Out:
# [10, 20, 30, 'Hi', True, (1+2j), 1234.454]

# %%
l3 = l3[::-1]

# %%
l3
# Out:
# [1234.454, (1+2j), True, 'Hi', 30, 20, 10]

# %%
l3 = l3[1::]

# %%
l3
# Out:
# [(1+2j), True, 'Hi', 30, 20, 10]

# %%
l3 = l3[1:]

# %%
l3
# Out:
# [True, 'Hi', 30, 20, 10]

# %%
l3 = l3[1::]

# %%
l3
# Out:
# ['Hi', 30, 20, 10]

# %%
l3.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 l3.sort()
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
l3 = l3[1::]

# %%
l3
# Out:
# [30, 20, 10]

# %%
l3.sort()

# %%
l3
# Out:
# [10, 20, 30]

# %%
l3.sort(reverse=True)

# %%
l3
# Out:
# [30, 20, 10]

# %%
l3.sort()

# %%
l3
# Out:
# [10, 20, 30]

# %%
l4=['o','q','s','a','p']
sorted(l4)
# Out:
# ['a', 'o', 'p', 'q', 's']

# %%
l4
# Out:
# ['o', 'q', 's', 'a', 'p']

# %%
l2
# Out:
# [0, 20, 30, 'Hi', True, (1+2j), 1234.454]

# %%
for i in l2:
    print(i)
# Out:
# 0
# 20
# 30
# Hi
# True
# (1+2j)
# 1234.454

# %%
for i in enumerate(l2):
    print(i)
# Out:
# (0, 0)
# (1, 20)
# (2, 30)
# (3, 'Hi')
# (4, True)
# (5, (1+2j))
# (6, 1234.454)

# %%
l1
# Out:
# [0,
#  20,
#  30,
#  'Hi',
#  True,
#  (1+2j),
#  1234.454,
#  10,
#  20,
#  30,
#  'Hi',
#  True,
#  (1+2j),
#  1234.454,
#  0,
#  20,
#  30,
#  'Hi',
#  True,
#  (1+2j),
#  1234.454]

# %%
l1.count(20)
# Out:
# 3

# %%
l1.count(True)
# Out:
# 3

# %%
all(l1)
# Out:
# False

# %%
any(l1)
# Out:
# True

# %%
l4
# Out:
# ['o', 'q', 's', 'a', 'p']

# %%
l5=[0,0]

# %%
all(l5)
# Out:
# False

# %%
l6=[1,3,5]

# %%
l6
# Out:
# [1, 3, 5]

# %%
all(l6)
# Out:
# True

# %%
any(l6)
# Out:
# True

# %% [markdown]
# # Tuple

# %%
t1=(1,2,3,4,5)

# %%
t1
# Out:
# (1, 2, 3, 4, 5)

# %%
type(t1)
# Out:
# tuple

# %%
t2=(1,2,'hi',True,1+2j,[1,2],[3,4],(1,5),('s','d'))
t2
# Out:
# (1, 2, 'hi', True, (1+2j), [1, 2], [3, 4], (1, 5), ('s', 'd'))

# %%
len(t2)
# Out:
# 9

# %%
len(t1)
# Out:
# 5

# %%
t2[0]
# Out:
# 1

# %%
t2
# Out:
# (1, 2, 'hi', True, (1+2j), [1, 2], [3, 4], (1, 5), ('s', 'd'))

# %%
t2[2][0]
# Out:
# 'h'

# %%
t2[-1]
# Out:
# ('s', 'd')

# %%
t2[:3]
# Out:
# (1, 2, 'hi')

# %%
t2[:-2]
# Out:
# (1, 2, 'hi', True, (1+2j), [1, 2], [3, 4])

# %%
t2[-3:]
# Out:
# ([3, 4], (1, 5), ('s', 'd'))

# %%
t2[:]
# Out:
# (1, 2, 'hi', True, (1+2j), [1, 2], [3, 4], (1, 5), ('s', 'd'))

# %%
l1
# Out:
# [0,
#  20,
#  30,
#  'Hi',
#  True,
#  (1+2j),
#  1234.454,
#  10,
#  20,
#  30,
#  'Hi',
#  True,
#  (1+2j),
#  1234.454,
#  0,
#  20,
#  30,
#  'Hi',
#  True,
#  (1+2j),
#  1234.454]

# %%
l2
# Out:
# [0, 20, 30, 'Hi', True, (1+2j), 1234.454]

# %%
t1
# Out:
# (1, 2, 3, 4, 5)

# %%
t2
# Out:
# (1, 2, 'hi', True, (1+2j), [1, 2], [3, 4], (1, 5), ('s', 'd'))

# %%
t3=t1

# %%
t3
# Out:
# (1, 2, 3, 4, 5)

# %%
t3[0]=7
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[153], line 1
# ----> 1 t3[0]=7
#
# TypeError: 'tuple' object does not support item assignment

# %%
del t3[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[154], line 1
# ----> 1 del t3[1]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
del t3 # deleting entire tuple is possible

# %%
t3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[156], line 1
# ----> 1 t3
#
# NameError: name 't3' is not defined

# %%
t2
# Out:
# (1, 2, 'hi', True, (1+2j), [1, 2], [3, 4], (1, 5), ('s', 'd'))

# %%
for i in t2:
    print(i)
# Out:
# 1
# 2
# hi
# True
# (1+2j)
# [1, 2]
# [3, 4]
# (1, 5)
# ('s', 'd')

# %%
for i in enumerate(t2):
    print(i)
# Out:
# (0, 1)
# (1, 2)
# (2, 'hi')
# (3, True)
# (4, (1+2j))
# (5, [1, 2])
# (6, [3, 4])
# (7, (1, 5))
# (8, ('s', 'd'))

# %%
l2
# Out:
# [0, 20, 30, 'Hi', True, (1+2j), 1234.454]

# %%
'Hi' in t2
# Out:
# False

# %%
t2
# Out:
# (1, 2, 'hi', True, (1+2j), [1, 2], [3, 4], (1, 5), ('s', 'd'))

# %%
type(t2)
# Out:
# tuple

# %%
type(l2)
# Out:
# list

# %%
'hi' in t2
# Out:
# True

# %%
t2
# Out:
# (1, 2, 'hi', True, (1+2j), [1, 2], [3, 4], (1, 5), ('s', 'd'))

# %%
if [1, 2] in t2:
    print('it is present')
else:
    print('it is not present')
# Out:
# it is present

# %%
t2.index(True)
# Out:
# 0

# %%
t2
# Out:
# (1, 2, 'hi', True, (1+2j), [1, 2], [3, 4], (1, 5), ('s', 'd'))

# %%
t2.index([1, 2])
# Out:
# 5

# %%
t2.index(True)
# Out:
# 0

# %%
if False in t2:
    print('it is present')
else:
    print('it is not')
# Out:
# it is not

# %%
t1
# Out:
# (1, 2, 3, 4, 5)

# %%
t3=t1

# %%
t3
# Out:
# (1, 2, 3, 4, 5)

# %%
t4=(2,5,65,6,33)
sorted(t4)
# Out:
# [2, 5, 6, 33, 65]

# %%
sorted(t4, reverse=True)
# Out:
# [65, 33, 6, 5, 2]
