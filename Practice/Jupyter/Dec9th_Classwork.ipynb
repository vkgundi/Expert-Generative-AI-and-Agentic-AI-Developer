# %% [markdown]
# # LIST

# %%
l=[10,20,30,40,50.60]

# %%
l
# Out:
# [10, 20, 30, 40, 50.6]

# %%
l[0]
# Out:
# 10

# %%
l[0]=100

# %%
;
# Out:
# ''

# %%
l
# Out:
# [100, 20, 30, 40, 50.6]

# %%
l[-1]=1000
l
# Out:
# [100, 20, 30, 40, 1000]

# %%
l1=[1,2.2,3,4,1+2j,True, 'vamshi']

# %%
l1
# Out:
# [1, 2.2, 3, 4, (1+2j), True, 'vamshi']

# %%
l2=l1.extend

# %%
l2
# Out:
# <function list.extend(iterable, /)>

# %%
l
# Out:
# [100, 20, 30, 40, 1000]

# %%
l1
# Out:
# [1, 2.2, 3, 4, (1+2j), True, 'vamshi']

# %%
l2
# Out:
# <function list.extend(iterable, /)>

# %%
l2=[]
l2
# Out:
# []

# %%
l2.extend(l1)

# %% [markdown]
# l2

# %%
l2
# Out:
# [1, 2.2, 3, 4, (1+2j), True, 'vamshi']

# %%
l2.extend(l)

# %%
l2
# Out:
# [1, 2.2, 3, 4, (1+2j), True, 'vamshi', 100, 20, 30, 40, 1000]

# %%
print(l)
# Out:
# [100, 20, 30, 40, 1000]

# %%
print(l1)
# Out:
# [1, 2.2, 3, 4, (1+2j), True, 'vamshi']

# %%
print(l2)
# Out:
# [1, 2.2, 3, 4, (1+2j), True, 'vamshi', 100, 20, 30, 40, 1000]

# %%
print(l)
print(l1)
print(l2)
# Out:
# [100, 20, 30, 40, 1000]
# [1, 2.2, 3, 4, (1+2j), True, 'vamshi']
# [1, 2.2, 3, 4, (1+2j), True, 'vamshi', 100, 20, 30, 40, 1000]

# %%
l
# Out:
# [100, 20, 30, 40, 1000]

# %%
l.index(40)
# Out:
# 3

# %%
l.index(200)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 l.index(200)
#
# ValueError: 200 is not in list

# %%
l.insert(4, 50)

# %%
l
# Out:
# [100, 20, 30, 40, 50, 1000]

# %%
l.insert(0,0)

# %%
l
# Out:
# [0, 100, 20, 30, 40, 50, 1000]

# %%
for i in l1:
    print(i)
# Out:
# 1
# 2.2
# 3
# 4
# (1+2j)
# True
# vamshi

# %%
for i in enumerate(l1):
    print(i)
# Out:
# (0, 1)
# (1, 2.2)
# (2, 3)
# (3, 4)
# (4, (1+2j))
# (5, True)
# (6, 'vamshi')

# %%
l
# Out:
# [0, 100, 20, 30, 40, 50, 1000]

# %%
l.pop()
# Out:
# 1000

# %%
l
# Out:
# [0, 100, 20, 30, 40, 50]

# %%
l.pop(1)
# Out:
# 100

# %%
l
# Out:
# [0, 20, 30, 40, 50]

# %%
l.insert(1,10)

# %%
l
# Out:
# [0, 10, 20, 30, 40, 50]

# %%
l1
# Out:
# [1, 2.2, 3, 4, (1+2j), True, 'vamshi']

# %%
l2
# Out:
# [1, 2.2, 3, 4, (1+2j), True, 'vamshi', 100, 20, 30, 40, 1000]

# %%
l1.remove(1)

# %%
l1
# Out:
# [2.2, 3, 4, (1+2j), True, 'vamshi']

# %%
l1.remove(2.2)

# %%
l1
# Out:
# [3, 4, (1+2j), True, 'vamshi']

# %%
l1.insert(1,2.0)

# %%
l1
# Out:
# [3, 2.0, 4, (1+2j), True, 'vamshi']

# %%
l1.insert(0,1)

# %%
l1
# Out:
# [1, 3, 2.0, 4, (1+2j), True, 'vamshi']

# %%
l1.remove(2.0)

# %%
l1
# Out:
# [1, 3, 4, (1+2j), True, 'vamshi']

# %%
l1.insert(1,2.0)

# %%
l1
# Out:
# [1, 2.0, 3, 4, (1+2j), True, 'vamshi']

# %%
l1.reverse()

# %%
l1
# Out:
# ['vamshi', True, (1+2j), 4, 3, 2.0, 1]

# %%
l1.reverse()

# %%
l1
# Out:
# [1, 2.0, 3, 4, (1+2j), True, 'vamshi']

# %%
l
# Out:
# [0, 10, 20, 30, 40, 50]

# %%
l3=[10,40,40,20,80]

# %%
l3
# Out:
# [10, 40, 40, 20, 80]

# %%
l3.sort()

# %%
l3
# Out:
# [10, 20, 40, 40, 80]

# %%
l3.sort(reverse=True)

# %%
l3
# Out:
# [80, 40, 40, 20, 10]

# %%
l3.sort(reverse=True)

# %%
l3
# Out:
# [80, 40, 40, 20, 10]

# %%
l4=[True,False]

# %%
l4.sort()

# %%
l4
# Out:
# [False, True]

# %%
l5=['m','A','t']

# %%
l5
# Out:
# ['m', 'A', 't']

# %%
l5.sort()

# %%
l5
# Out:
# ['A', 'm', 't']

# %%
l3.sort()

# %%
l3
# Out:
# [10, 20, 40, 40, 80]

# %%
l
# Out:
# [0, 10, 20, 30, 40, 50]

# %%
10 in l
# Out:
# True

# %%
200 in l
# Out:
# False

# %%
all(l)
# Out:
# False

# %%
l.remove(0)
l
# Out:
# [10, 20, 30, 40, 50]

# %%
any(l)
# Out:
# True

# %%
all(l)
# Out:
# True

# %%
l.append(0)
l
# Out:
# [10, 20, 30, 40, 50, 0, 0]

# %%
all(l)
# Out:
# False

# %%
any(l)
# Out:
# True

# %%
l5
# Out:
# ['A', 'm', 't']

# %%
l6=[0,0]

# %%
l6
# Out:
# [0, 0]

# %%
any(l)
# Out:
# True

# %%
type(l)
# Out:
# list

# %% [markdown]
# # TUPLE

# %%
t = (10,20,30)

# %%
t
# Out:
# (10, 20, 30)

# %%
type(t)
# Out:
# tuple

# %%
t.count(10)
# Out:
# 1

# %%
t1=(1,1,3,3,3,4)

# %%
t1
# Out:
# (1, 1, 3, 3, 3, 4)

# %%
t1.count(1)
# Out:
# 2

# %%
t1.index(4)
# Out:
# 5

# %%
t1.index(1)
# Out:
# 0

# %%
for i in t1:
    print(i)
# Out:
# 1
# 1
# 3
# 3
# 3
# 4

# %%
t1[:]
# Out:
# (1, 1, 3, 3, 3, 4)

# %%
t1[1:2]
# Out:
# (1,)

# %%
t1
# Out:
# (1, 1, 3, 3, 3, 4)

# %%
t1[1:-1]
# Out:
# (1, 3, 3, 3)

# %% [raw]
# for i in enumerate(t1):
# print(i)

# %%
for i in enumerate(t1):
    print(i)
# Out:
# (0, 1)
# (1, 1)
# (2, 3)
# (3, 3)
# (4, 3)
# (5, 4)

# %%
t2=([1,2,3],True,False,(1+4j),1,'Hi')

# %%
t2
# Out:
# ([1, 2, 3], True, False, (1+4j), 1, 'Hi')

# %%
te
