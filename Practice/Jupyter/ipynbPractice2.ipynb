# %% [markdown]
# # we work with Python numbers

# %% [markdown]
# 5

# %%
5
# Out:
# 5

# %%
6
# Out:
# 6

# %%
7
# Out:
# 7

# %%
-5
# Out:
# -5

# %%
5+6
# Out:
# 11

# %%
5+6-7*3-7
# Out:
# -17

# %%
5+6-(7*3)-7
# Out:
# -17

# %% [markdown]
# 5+6-7*(3-7)

# %%
5+6-7*(3-7)
# Out:
# 39

# %%
4+3
# Out:
# 7

# %%
_
# Out:
# 7

# %%
_ + 3
# Out:
# 10

# %%
_ + 3
# Out:
# 13

# %%
_=4

# %%
_-4
# Out:
# 0

# %%
nareshit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 nareshit
#
# NameError: name 'nareshit' is not defined

# %%
'nareshit'
# Out:
# 'nareshit'

# %%
"naresh"
# Out:
# 'naresh'

# %%
'''vamshi'''
# Out:
# 'vamshi'

# %%
'''vamshi
krishna'''
# Out:
# 'vamshi\nkrishna'

# %%
'vamshi krisna'
# Out:
# 'vamshi krisna'

# %%
"vamshi krishna"
# Out:
# 'vamshi krishna'
